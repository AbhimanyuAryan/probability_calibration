# %%
import os, sys
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re

# %%
def add_datepart(df, fldname, drop=True, time=False, errors="raise"):
    fld = df[fldname]
    fld_dtype = fld.dtype
    if isinstance(fld_dtype, pd.core.dtypes.dtypes.DatetimeTZDtype):
        fld_dtype = np.datetime64

    if not np.issubdtype(fld_dtype, np.datetime64):
        df[fldname] = fld = pd.to_datetime(fld, infer_datetime_format=True, errors=errors)
    targ_pre = re.sub('[Dd]ate$', '', fldname)
    attr = ['Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Dayofyear',
            'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
    if time: attr = attr + ['Hour', 'Minute', 'Second']
    for n in attr: df[targ_pre + n] = getattr(fld.dt, n.lower())
    df[targ_pre + 'Elapsed'] = fld.astype(np.int64) // 10 ** 9
    if drop: df.drop(fldname, axis=1, inplace=True)

# %%
df_raw = pd.read_csv('data.csv', low_memory=False, 
                     parse_dates=["event_time"])

# %%
# Data Dec 17,2018 to Jan 30,2019
# Train Model on 17th to Jan 13

# predict values for Jan 14 - Jan 20
# what happends to data from 20th - 30th

# %%
df_raw.head()
# Out:
#                   record_id         city_key          event_time  weekday  \
# 0  5c1699b0c3658c25008e1192  city_chennai_v2 2018-12-17 00:00:08  weekday
# 1  5c1699b72dd2b92500f5f400   city_mumbai_v2 2018-12-17 00:00:15  weekday
# 2  5c1699df4fb96a2400166132   city_mumbai_v2 2018-12-17 00:00:55  weekday
# 3  5c1699f405cbce26002ff832  city_kolkata_v2 2018-12-17 00:01:16  weekday
# 4  5c1699fb02f88224006901f5  city_chennai_v2 2018-12-17 00:01:23  weekday
#
#                      category_key           rptcatg                    req_id  \
# 0  professional_bathroom_cleaning  Cleaning - Other  5c1699d714bd522300fae954
# 1                    electricians               EPC  5c1699ed70fa4f2500d66e7c
# 2                   salon_at_home     Salon at Home                       NaN
# 3                   salon_at_home     Salon at Home                       NaN
# 4                        plumbers               EPC  5c169a6c8c954c2200693538
#
#    session_group
# 0           3022
# 1           3303
# 2           3330
# 3           3330
# 4           3303

# %%
display(df_raw.tail().T)
# Out:
#                                  816525                    816526  \
# record_id      5c44bde3e55c0a2500c63f15  5c44bde52225782400b89bcf
# city_key              city_hyderabad_v2            city_mumbai_v2
# event_time          2019-01-20 23:58:51       2019-01-20 23:58:53
# weekday                          sunday                    sunday
# category_key              salon_at_home             salon_at_home
# rptcatg                   Salon at Home             Salon at Home
# req_id                              NaN  5c44be32fb1ebb2700dbc7b0
# session_group                        33                        33
#
#                                  816527                    816528  \
# record_id      5c44bdecdaae8f2400a22225  5c44bdf966fee926000b3a9d
# city_key              city_bangalore_v2            city_mumbai_v2
# event_time          2019-01-20 23:59:00       2019-01-20 23:59:13
# weekday                          sunday                    sunday
# category_key              salon_at_home          microwave_repair
# rptcatg                   Salon at Home          Appliance Repair
# req_id         5c44be719daac92400f7d277  5c44be21d248a42500c783b8
# session_group                        33                        20
#
#                                  816529
# record_id      5c44be1ca48ea124006e00d2
# city_key                  city_delhi_v2
# event_time          2019-01-20 23:59:48
# weekday                          sunday
# category_key              salon_at_home
# rptcatg                   Salon at Home
# req_id                              NaN
# session_group                        33

# %%
# Checking null values
display(df_raw.isnull().sum().sort_index()/len(df_raw))
# Out:
# category_key     0.000000
# city_key         0.000000
# event_time       0.000000
# record_id        0.000000
# req_id           0.543902
# rptcatg          0.000000
# session_group    0.000000
# weekday          0.000000
# dtype: float64

# %%
add_datepart(df_raw, 'event_time')
display(df_raw.head().T)
# Out:
#                                                          0  \
# record_id                         5c1699b0c3658c25008e1192
# city_key                                   city_chennai_v2
# weekday                                            weekday
# category_key                professional_bathroom_cleaning
# rptcatg                                   Cleaning - Other
# req_id                            5c1699d714bd522300fae954
# session_group                                         3022
# event_timeYear                                        2018
# event_timeMonth                                         12
# event_timeWeek                                          51
# event_timeDay                                           17
# event_timeDayofweek                                      0
# event_timeDayofyear                                    351
# event_timeIs_month_end                               False
# event_timeIs_month_start                             False
# event_timeIs_quarter_end                             False
# event_timeIs_quarter_start                           False
# event_timeIs_year_end                                False
# event_timeIs_year_start                              False
# event_timeElapsed                               1545004808
#
#                                                    1  \
# record_id                   5c1699b72dd2b92500f5f400
# city_key                              city_mumbai_v2
# weekday                                      weekday
# category_key                            electricians
# rptcatg                                          EPC
# req_id                      5c1699ed70fa4f2500d66e7c
# session_group                                   3303
# event_timeYear                                  2018
# event_timeMonth                                   12
# event_timeWeek                                    51
# event_timeDay                                     17
# event_timeDayofweek                                0
# event_timeDayofyear                              351
# event_timeIs_month_end                         False
# event_timeIs_month_start                       False
# event_timeIs_quarter_end                       False
# event_timeIs_quarter_start                     False
# event_timeIs_year_end                          False
# event_timeIs_year_start                        False
# event_timeElapsed                         1545004815
#
#                                                    2  \
# record_id                   5c1699df4fb96a2400166132
# city_key                              city_mumbai_v2
# weekday                                      weekday
# category_key                           salon_at_home
# rptcatg                                Salon at Home
# req_id                                           NaN
# session_group                                   3330
# event_timeYear                                  2018
# event_timeMonth                                   12
# event_timeWeek                                    51
# event_timeDay                                     17
# event_timeDayofweek                                0
# event_timeDayofyear                              351
# event_timeIs_month_end                         False
# event_timeIs_month_start                       False
# event_timeIs_quarter_end                       False
# event_timeIs_quarter_start                     False
# event_timeIs_year_end                          False
# event_timeIs_year_start                        False
# event_timeElapsed                         1545004855
#
#                                                    3                         4
# record_id                   5c1699f405cbce26002ff832  5c1699fb02f88224006901f5
# city_key                             city_kolkata_v2           city_chennai_v2
# weekday                                      weekday                   weekday
# category_key                           salon_at_home                  plumbers
# rptcatg                                Salon at Home                       EPC
# req_id                                           NaN  5c169a6c8c954c2200693538
# session_group                                   3330                      3303
# event_timeYear                                  2018                      2018
# event_timeMonth                                   12                        12
# event_timeWeek                                    51                        51
# event_timeDay                                     17                        17
# event_timeDayofweek                                0                         0
# event_timeDayofyear                              351                       351
# event_timeIs_month_end                         False                     False
# event_timeIs_month_start                       False                     False
# event_timeIs_quarter_end                       False                     False
# event_timeIs_quarter_start                     False                     False
# event_timeIs_year_end                          False                     False
# event_timeIs_year_start                        False                     False
# event_timeElapsed                         1545004876                1545004883

# %%
df_raw.shape
# Out:
# (816530, 20)

# %%
df_raw['session_group'].head()
# Out:
# 0    3022
# 1    3303
# 2    3330
# 3    3330
# 4    3303
# Name: session_group, dtype: int64

# %%
df_raw['req_id'].fillna(0, inplace=True)

# %%
df_raw.head()
# Out:
#                   record_id         city_key  weekday  \
# 0  5c1699b0c3658c25008e1192  city_chennai_v2  weekday
# 1  5c1699b72dd2b92500f5f400   city_mumbai_v2  weekday
# 2  5c1699df4fb96a2400166132   city_mumbai_v2  weekday
# 3  5c1699f405cbce26002ff832  city_kolkata_v2  weekday
# 4  5c1699fb02f88224006901f5  city_chennai_v2  weekday
#
#                      category_key           rptcatg                    req_id  \
# 0  professional_bathroom_cleaning  Cleaning - Other  5c1699d714bd522300fae954
# 1                    electricians               EPC  5c1699ed70fa4f2500d66e7c
# 2                   salon_at_home     Salon at Home                         0
# 3                   salon_at_home     Salon at Home                         0
# 4                        plumbers               EPC  5c169a6c8c954c2200693538
#
#    session_group  event_timeYear  event_timeMonth  event_timeWeek  \
# 0           3022            2018               12              51
# 1           3303            2018               12              51
# 2           3330            2018               12              51
# 3           3330            2018               12              51
# 4           3303            2018               12              51
#
#    event_timeDay  event_timeDayofweek  event_timeDayofyear  \
# 0             17                    0                  351
# 1             17                    0                  351
# 2             17                    0                  351
# 3             17                    0                  351
# 4             17                    0                  351
#
#    event_timeIs_month_end  event_timeIs_month_start  event_timeIs_quarter_end  \
# 0                   False                     False                     False
# 1                   False                     False                     False
# 2                   False                     False                     False
# 3                   False                     False                     False
# 4                   False                     False                     False
#
#    event_timeIs_quarter_start  event_timeIs_year_end  event_timeIs_year_start  \
# 0                       False                  False                    False
# 1                       False                  False                    False
# 2                       False                  False                    False
# 3                       False                  False                    False
# 4                       False                  False                    False
#
#    event_timeElapsed
# 0         1545004808
# 1         1545004815
# 2         1545004855
# 3         1545004876
# 4         1545004883

# %%
df_raw.loc[df_raw['req_id'] != 0, 'req_id'] = 1

# %%
df_raw.head()
# Out:
#                   record_id         city_key  weekday  \
# 0  5c1699b0c3658c25008e1192  city_chennai_v2  weekday
# 1  5c1699b72dd2b92500f5f400   city_mumbai_v2  weekday
# 2  5c1699df4fb96a2400166132   city_mumbai_v2  weekday
# 3  5c1699f405cbce26002ff832  city_kolkata_v2  weekday
# 4  5c1699fb02f88224006901f5  city_chennai_v2  weekday
#
#                      category_key           rptcatg  req_id  session_group  \
# 0  professional_bathroom_cleaning  Cleaning - Other       1           3022
# 1                    electricians               EPC       1           3303
# 2                   salon_at_home     Salon at Home       0           3330
# 3                   salon_at_home     Salon at Home       0           3330
# 4                        plumbers               EPC       1           3303
#
#    event_timeYear  event_timeMonth  event_timeWeek  event_timeDay  \
# 0            2018               12              51             17
# 1            2018               12              51             17
# 2            2018               12              51             17
# 3            2018               12              51             17
# 4            2018               12              51             17
#
#    event_timeDayofweek  event_timeDayofyear  event_timeIs_month_end  \
# 0                    0                  351                   False
# 1                    0                  351                   False
# 2                    0                  351                   False
# 3                    0                  351                   False
# 4                    0                  351                   False
#
#    event_timeIs_month_start  event_timeIs_quarter_end  \
# 0                     False                     False
# 1                     False                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                     False
#
#    event_timeIs_quarter_start  event_timeIs_year_end  event_timeIs_year_start  \
# 0                       False                  False                    False
# 1                       False                  False                    False
# 2                       False                  False                    False
# 3                       False                  False                    False
# 4                       False                  False                    False
#
#    event_timeElapsed
# 0         1545004808
# 1         1545004815
# 2         1545004855
# 3         1545004876
# 4         1545004883

# %%
from pandas.api.types import is_string_dtype

def train_cats(df):
    for n,c in df.items():
        if is_string_dtype(c): df[n] = c.astype('category').cat.as_ordered()

# %%
train_cats(df_raw)

# %%
df_raw.head()
# Out:
#                   record_id         city_key  weekday  \
# 0  5c1699b0c3658c25008e1192  city_chennai_v2  weekday
# 1  5c1699b72dd2b92500f5f400   city_mumbai_v2  weekday
# 2  5c1699df4fb96a2400166132   city_mumbai_v2  weekday
# 3  5c1699f405cbce26002ff832  city_kolkata_v2  weekday
# 4  5c1699fb02f88224006901f5  city_chennai_v2  weekday
#
#                      category_key           rptcatg  req_id  session_group  \
# 0  professional_bathroom_cleaning  Cleaning - Other       1           3022
# 1                    electricians               EPC       1           3303
# 2                   salon_at_home     Salon at Home       0           3330
# 3                   salon_at_home     Salon at Home       0           3330
# 4                        plumbers               EPC       1           3303
#
#    event_timeYear  event_timeMonth  event_timeWeek  event_timeDay  \
# 0            2018               12              51             17
# 1            2018               12              51             17
# 2            2018               12              51             17
# 3            2018               12              51             17
# 4            2018               12              51             17
#
#    event_timeDayofweek  event_timeDayofyear  event_timeIs_month_end  \
# 0                    0                  351                   False
# 1                    0                  351                   False
# 2                    0                  351                   False
# 3                    0                  351                   False
# 4                    0                  351                   False
#
#    event_timeIs_month_start  event_timeIs_quarter_end  \
# 0                     False                     False
# 1                     False                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                     False
#
#    event_timeIs_quarter_start  event_timeIs_year_end  event_timeIs_year_start  \
# 0                       False                  False                    False
# 1                       False                  False                    False
# 2                       False                  False                    False
# 3                       False                  False                    False
# 4                       False                  False                    False
#
#    event_timeElapsed
# 0         1545004808
# 1         1545004815
# 2         1545004855
# 3         1545004876
# 4         1545004883

# %%
# Feature Format
# os.makedirs('tmp', exist_ok=True)
# df_raw.to_feather('tmp/uc-data')

# %%
# Read feather format
# df_raw = pd.read_feather('tmp/uc-data')

# %%
from pandas.api.types import is_numeric_dtype

def fix_missing(df, col, name, na_dict):
    if is_numeric_dtype(col):
        if pd.isnull(col).sum() or (name in na_dict):
            df[name+'_na'] = pd.isnull(col)
            filler = na_dict[name] if name in na_dict else col.median()
            df[name] = col.fillna(filler)
            na_dict[name] = filler
    return na_dict

def numericalize(df, col, name, max_n_cat):
    if not is_numeric_dtype(col) and ( max_n_cat is None or len(col.cat.categories)>max_n_cat):
        df[name] = pd.Categorical(col).codes+1


def proc_df(df, y_fld=None, skip_flds=None, ignore_flds=None, do_scale=False, na_dict=None,
            preproc_fn=None, max_n_cat=None, subset=None, mapper=None):
    if not ignore_flds: ignore_flds=[]
    if not skip_flds: skip_flds=[]
    if subset: df = get_sample(df,subset)
    else: df = df.copy()
    ignored_flds = df.loc[:, ignore_flds]
    df.drop(ignore_flds, axis=1, inplace=True)
    if preproc_fn: preproc_fn(df)
    if y_fld is None: y = None
    else:
        if not is_numeric_dtype(df[y_fld]): df[y_fld] = pd.Categorical(df[y_fld]).codes
        y = df[y_fld].values
        skip_flds += [y_fld]
    df.drop(skip_flds, axis=1, inplace=True)

    if na_dict is None: na_dict = {}
    else: na_dict = na_dict.copy()
    na_dict_initial = na_dict.copy()
    for n,c in df.items(): na_dict = fix_missing(df, c, n, na_dict)
    if len(na_dict_initial.keys()) > 0:
        df.drop([a + '_na' for a in list(set(na_dict.keys()) - set(na_dict_initial.keys()))], axis=1, inplace=True)
    if do_scale: mapper = scale_vars(df, mapper)
    for n,c in df.items(): numericalize(df, c, n, max_n_cat)
    df = pd.get_dummies(df, dummy_na=True)
    df = pd.concat([ignored_flds, df], axis=1)
    res = [df, y, na_dict]
    if do_scale: res = res + [mapper]
    return res

# %%
df, y, nas = proc_df(df_raw, 'req_id')

# %%
df.head()
# Out:
#    record_id  city_key  weekday  category_key  rptcatg  session_group  \
# 0          3         4        4            10        2           3022
# 1          6         9        4             4        3           3303
# 2         12         9        4            17        8           3330
# 3         17         8        4            17        8           3330
# 4         19         4        4             9        3           3303
#
#    event_timeYear  event_timeMonth  event_timeWeek  event_timeDay  \
# 0            2018               12              51             17
# 1            2018               12              51             17
# 2            2018               12              51             17
# 3            2018               12              51             17
# 4            2018               12              51             17
#
#    event_timeDayofweek  event_timeDayofyear  event_timeIs_month_end  \
# 0                    0                  351                   False
# 1                    0                  351                   False
# 2                    0                  351                   False
# 3                    0                  351                   False
# 4                    0                  351                   False
#
#    event_timeIs_month_start  event_timeIs_quarter_end  \
# 0                     False                     False
# 1                     False                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                     False
#
#    event_timeIs_quarter_start  event_timeIs_year_end  event_timeIs_year_start  \
# 0                       False                  False                    False
# 1                       False                  False                    False
# 2                       False                  False                    False
# 3                       False                  False                    False
# 4                       False                  False                    False
#
#    event_timeElapsed
# 0         1545004808
# 1         1545004815
# 2         1545004855
# 3         1545004876
# 4         1545004883

# %%
m = RandomForestClassifier(n_jobs=-1)
m.fit(df, y)
m.score(df,y)
# Out:
# /Users/abhimanyuaryan/anaconda/lib/python3.6/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.9576390334709074

# %% [markdown]
# # Splitting train and test

# %%
df[df.event_timeDay >= 14].count()
# Out:
# record_id                     546869
# city_key                      546869
# weekday                       546869
# category_key                  546869
# rptcatg                       546869
# session_group                 546869
# event_timeYear                546869
# event_timeMonth               546869
# event_timeWeek                546869
# event_timeDay                 546869
# event_timeDayofweek           546869
# event_timeDayofyear           546869
# event_timeIs_month_end        546869
# event_timeIs_month_start      546869
# event_timeIs_quarter_end      546869
# event_timeIs_quarter_start    546869
# event_timeIs_year_end         546869
# event_timeIs_year_start       546869
# event_timeElapsed             546869
# dtype: int64

# %%
df.shape
# Out:
# (816530, 19)

# %%
def split_vals(a,n): return a[:n].copy(), a[n:].copy()

n_valid = 546869  # same as Kaggle's test set size
n_trn = len(df)-n_valid
raw_train, raw_valid = split_vals(df_raw, n_trn)
X_train, X_valid = split_vals(df, n_trn)
y_train, y_valid = split_vals(y, n_trn)

X_train.shape, y_train.shape, X_valid.shape
# Out:
# ((269661, 19), (269661,), (546869, 19))

# %%
def cross_entropy(x, y, epsilon=1e-12):
    """
    Computes cross entropy between targets (encoded as one-hot vectors)
    and predictions. 
    Input: predictions (N, k) ndarray
           targets (N, k) ndarray        
    Returns: scalar
    """
    x = np.clip(x, epsilon, 1. - epsilon)
    N = x.shape[0]
    ce = -np.sum(y*np.log(x+1e-9))/N
    return ce
#predictions = np.array([[0.25,0.25,0.25,0.25],
#                        [0.01,0.01,0.01,0.96]])
#targets = np.array([[0,0,0,1],
#                  [0,0,0,1]])
#ans = 0.71355817782  #Correct answer
#x = cross_entropy(predictions, targets)
#print(np.isclose(x,ans))

# %%
def print_score(m):
    res = [cross_entropy(m.predict(X_train), y_train), cross_entropy(m.predict(X_valid), y_valid),
                m.score(X_train, y_train), m.score(X_valid, y_valid)]
    if hasattr(m, 'oob_score_'): res.append(m.oob_score_)
    print(res)

# %%
# Random Forest Classifier
m = RandomForestClassifier(n_jobs=-1)
# %time m.fit(X_train, y_train)
print_score(m)
# Out:
# /Users/abhimanyuaryan/anaconda/lib/python3.6/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# CPU times: user 5.11 s, sys: 287 ms, total: 5.39 s
# Wall time: 1.34 s
# [0.6690948000670042, 5.436862385938188, 0.9592117510503929, 0.5431209302410632]

# %%
X_valid.head()
# Out:
#         record_id  city_key  weekday  category_key  rptcatg  session_group  \
# 269661      47045         2        4            18        9             33
# 269662      47047         2        4            17        8             33
# 269663      47048         6        4             3        3             23
# 269664      47051         8        4             5        5             33
# 269665      47052         9        4            18        9             33
#
#         event_timeYear  event_timeMonth  event_timeWeek  event_timeDay  \
# 269661            2018               12              51             18
# 269662            2018               12              51             18
# 269663            2018               12              51             18
# 269664            2018               12              51             18
# 269665            2018               12              51             18
#
#         event_timeDayofweek  event_timeDayofyear  event_timeIs_month_end  \
# 269661                    1                  352                   False
# 269662                    1                  352                   False
# 269663                    1                  352                   False
# 269664                    1                  352                   False
# 269665                    1                  352                   False
#
#         event_timeIs_month_start  event_timeIs_quarter_end  \
# 269661                     False                     False
# 269662                     False                     False
# 269663                     False                     False
# 269664                     False                     False
# 269665                     False                     False
#
#         event_timeIs_quarter_start  event_timeIs_year_end  \
# 269661                       False                  False
# 269662                       False                  False
# 269663                       False                  False
# 269664                       False                  False
# 269665                       False                  False
#
#         event_timeIs_year_start  event_timeElapsed
# 269661                    False         1545177524
# 269662                    False         1545177534
# 269663                    False         1545177536
# 269664                    False         1545177570
# 269665                    False         1545177574

# %%
y_valid
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %%
predictions = X_valid.values
targets = y_valid

preds = m.predict(predictions)
(preds.T==targets).mean()
# Out:
# 0.5431209302410632

# %%
preds
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
y_valid
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %%
preds.shape
# Out:
# (546869,)

# %%
m = RandomForestClassifier(n_estimators = 40, n_jobs=-1)
# %time m.fit(X_train, y_train)
print_score(m)
# Out:
# CPU times: user 21.5 s, sys: 859 ms, total: 22.4 s
# Wall time: 3.38 s
# [0.051256027109835206, 5.145695955699478, 0.9967626019335388, 0.5465641680183005]

# %%
predictions = X_valid.values
targets = y_valid

preds = m.predict(predictions)
(preds.T==targets).mean()
# Out:
# 0.5450299797574922

# %% [markdown]
# # Feature Importance

# %%
feature_importances = pd.DataFrame(m.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance', ascending=False)

# %%
feature_importances
# Out:
#                             importance
# record_id                     0.459393
# event_timeElapsed             0.334402
# city_key                      0.082250
# session_group                 0.056452
# category_key                  0.030078
# rptcatg                       0.021857
# event_timeDayofyear           0.003938
# event_timeDayofweek           0.003908
# event_timeDay                 0.003860
# weekday                       0.001906
# event_timeWeek                0.001119
# event_timeYear                0.000227
# event_timeMonth               0.000224
# event_timeIs_quarter_end      0.000072
# event_timeIs_year_start       0.000070
# event_timeIs_month_start      0.000067
# event_timeIs_quarter_start    0.000062
# event_timeIs_month_end        0.000060
# event_timeIs_year_end         0.000054

# %%
to_drop = ['event_timeDayofyear', 'event_timeDayofweek','event_timeDay', 'weekday', 'event_timeWeek', 'event_timeYear',
'event_timeMonth', 'event_timeIs_quarter_end', 'event_timeIs_year_start','event_timeIs_month_start', 
'event_timeIs_quarter_start', 'event_timeIs_month_end', 'event_timeIs_year_end']

# %%
len(to_drop)
# Out:
# 13

# %%
df_keep = X_train.copy()

# %%
df_keep.head()
# Out:
#    record_id  city_key  weekday  category_key  rptcatg  session_group  \
# 0          3         4        4            10        2           3022
# 1          6         9        4             4        3           3303
# 2         12         9        4            17        8           3330
# 3         17         8        4            17        8           3330
# 4         19         4        4             9        3           3303
#
#    event_timeYear  event_timeMonth  event_timeWeek  event_timeDay  \
# 0            2018               12              51             17
# 1            2018               12              51             17
# 2            2018               12              51             17
# 3            2018               12              51             17
# 4            2018               12              51             17
#
#    event_timeDayofweek  event_timeDayofyear  event_timeIs_month_end  \
# 0                    0                  351                   False
# 1                    0                  351                   False
# 2                    0                  351                   False
# 3                    0                  351                   False
# 4                    0                  351                   False
#
#    event_timeIs_month_start  event_timeIs_quarter_end  \
# 0                     False                     False
# 1                     False                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                     False
#
#    event_timeIs_quarter_start  event_timeIs_year_end  event_timeIs_year_start  \
# 0                       False                  False                    False
# 1                       False                  False                    False
# 2                       False                  False                    False
# 3                       False                  False                    False
# 4                       False                  False                    False
#
#    event_timeElapsed
# 0         1545004808
# 1         1545004815
# 2         1545004855
# 3         1545004876
# 4         1545004883

# %%
df_keep.drop(to_drop, axis=1,inplace=True)

# %%
df_keep.head()
# Out:
#    record_id  city_key  category_key  rptcatg  session_group  \
# 0          3         4            10        2           3022
# 1          6         9             4        3           3303
# 2         12         9            17        8           3330
# 3         17         8            17        8           3330
# 4         19         4             9        3           3303
#
#    event_timeElapsed
# 0         1545004808
# 1         1545004815
# 2         1545004855
# 3         1545004876
# 4         1545004883

# %%
frt = RandomForestClassifier(n_estimators = 40, n_jobs=-1)
# %time frt.fit(df_keep, y_train)
frt.score(df_keep, y_train)
# Out:
# CPU times: user 27.6 s, sys: 790 ms, total: 28.4 s
# Wall time: 4.13 s
# 0.9959208042690637

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression

logi = LogisticRegression(C=0.1, dual=True)
# %time logi.fit(X_train, y_train);
print_score(logi)
# Out:
# /Users/abhimanyuaryan/anaconda/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/abhimanyuaryan/anaconda/lib/python3.6/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# CPU times: user 9.54 s, sys: 138 ms, total: 9.68 s
# Wall time: 9.73 s
# [4.780412236880623, 8.055124597052732, 0.4917136701265663, 0.5224487034372034]

# %%
# Naive Bayes Classifer
from sklearn.naive_bayes import MultinomialNB
mul_nb = MultinomialNB(class_prior=[0.25, 0.5])
# %time mul_nb.fit(X_train, y_train);
print_score(mul_nb)
# Out:
# CPU times: user 314 ms, sys: 76.1 ms, total: 390 ms
# Wall time: 372 ms
# [5.376503699794646, 1.9233505547273724, 0.5234275627547179, 0.4855276126458073]

# %% [markdown]
# # Neural Network to get better prediction
# # NBSVM++ Navive Bias SVM
